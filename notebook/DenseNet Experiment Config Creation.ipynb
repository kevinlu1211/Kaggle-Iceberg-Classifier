# %% [markdown]
# #### DenseNet

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from torch.nn import functional as F
import torch.nn as nn
from torch.autograd import Variable
from tqdm import tqdm
from collections import OrderedDict
from uuid import uuid4

# %%
def make_initial_block_config(n_init_features, bias=False):
    prefix = "initial_block"
    block_config = {}
    block_config[f"{prefix}.conv_0"] = {
        "name": "Conv2d",
        "parameters": {
          "in_channels": 3,
          "out_channels": n_init_features,
          "kernel_size": 5,
          "stride": 1,
          "bias": bias
        }
      }
    block_config[f"{prefix}.batch_norm_0"] = {
        "name": "BatchNorm2d",
        "parameters": {
          "num_features": n_init_features
        }
      }
    block_config[f"{prefix}.non_linearity_0"] = {
        "name": "LeakyReLU",
        "parameters": {
          "inplace": True
        }
    }
    return block_config

# %%
def make_dense_block_config(block_i, n_layers, n_input_features, growth_rate, bottleneck_size, dropout_rate, bias=False):
    block_config = OrderedDict()
    for layer_i in range(n_layers):
        layer_config = make_dense_layer_config(block_i, layer_i, n_input_features + layer_i * growth_rate, growth_rate,
                           bottleneck_size, dropout_rate, bias)
        block_config.update(**layer_config)
    return block_config

# %%
def make_dense_layer_config(block_i, layer_i, n_input_features, growth_rate, bottleneck_size, dropout_rate, bias=False):
    layer_config = OrderedDict()
    prefix = f"denseblock_{block_i}.layer_{layer_i}"
    layer_config[f"{prefix}.batch_norm_0"] = {
        "name": "BatchNorm2d",
        "parameters": {
          "num_features": n_input_features
        }
      }
    layer_config[f"{prefix}.non_linearity_0"] = {
        "name": "LeakyReLU",
        "parameters": {
          "inplace": True
        }
      }
    layer_config[f"{prefix}.conv_0"] = {
        "name": "Conv2d",
        "parameters": {
          "in_channels": n_input_features,
          "out_channels": growth_rate * bottleneck_size,
          "kernel_size": 1,
          "stride": 1,
          "bias": bias
        }
      }
    layer_config[f"{prefix}.dropout_0"] = {
            "name": "Dropout",
            "parameters": {
                "p": dropout_rate
            }
          }
    layer_config[f"{prefix}.batch_norm_1"] = {
        "name": "BatchNorm2d",
        "parameters": {
          "num_features": growth_rate * bottleneck_size
        }
      }
    layer_config[f"{prefix}.non_linearity_1"] = {
        "name": "LeakyReLU",
        "parameters": {
          "inplace": True
        }
      }
    layer_config[f"{prefix}.conv_1"] = {
        "name": "Conv2d",
        "parameters": {
          "in_channels": growth_rate * bottleneck_size,
          "out_channels": growth_rate,
          "kernel_size": 3,
          "stride": 1,
          "padding": 1,
          "bias": bias
        }
      }
    layer_config[f"{prefix}.dropout_1"] = {
        "name": "Dropout",
        "parameters": {
            "p": dropout_rate
        }
      }
    return layer_config

# %%
def make_transition_layer_config(block_i, n_input_features, n_output_features, bias=False):
    prefix = f"transition_{block_i}"
    layer_config = OrderedDict()
    layer_config[f"{prefix}.batch_norm_0"] = {
        "name": "BatchNorm2d",
        "parameters": {
          "num_features": n_input_features
        }
      }
    layer_config[f"{prefix}.non_linearity_0"] = {
        "name": "LeakyReLU",
        "parameters": {
          "inplace": True
        }
      }
    layer_config[f"{prefix}.conv_0"] = {
        "name": "Conv2d",
        "parameters": {
          "in_channels": n_input_features,
          "out_channels": n_output_features,
          "kernel_size": 1,
          "stride": 1,
          "padding": 1,
          "bias": bias
        }
    }
    layer_config[f"{prefix}.pooling_0"] = {
        "name": "AvgPool2d",
        "parameters": {
           "kernel_size": 2,
            "stride": 2
        }
    }
    return layer_config

# %%
config = {
    "model": {
        "name": "DenseNet",
        "config": {
          "n_initial_features": 32,
          "block_config": [6, 16, 24, 16],
          "growth_rate": 16, 
          "bottleneck_size": 4
        }
    }, 
    "optimizer": {
    "name": "ADAM",
    "parameters": {
      "weight_decay": 0.0001,
      "lr": 0.00005
    }
  },
  "loss_function": {
    "name": "BCELoss"
  },
  "output_transformation": {
    "name": "sigmoid"
  },
  "trainer_delegate": {
    "name": "DenseNet"
  },
  "data_source_delegate": {
    "name": "DenseNet",
    "parameters": {
      "batch_size": 32,
      "training_data_path": "/home/kevin/workspace/Kaggle/Iceberg-Classifier-Challenge/src/data/train.json",
      "testing_data_path": "/home/kevin/workspace/Kaggle/Iceberg-Classifier-Challenge/src/data/test.json"
    }
  },
  "saver_delegate": {
    "name": "DenseNet"
  },
  "n_epochs": 35
}

# %%
n_initial_features = 32
layers_per_block = [4, 8, 12, 8]
growth_rate = 8
bottleneck_size = 2

# %%
n_features = n_initial_features
model_config = {}
initial_block = make_initial_block_config(n_features)
model_config.update(**initial_block)
for block_i, n_layers in enumerate(layers_per_block):
    block_config = make_dense_block_config(block_i, n_layers, n_features, growth_rate, bottleneck_size, dropout_rate)
    model_config.update(**block_config)
    n_features = n_features + growth_rate * n_layers
    if block_i != len(block_config) - 1:
        trans = make_transition_layer_config(block_i, n_input_features=n_features, n_output_features=n_features // 2)
        n_features = n_features // 2
        model_config.update(**trans)

# %%
config["model"]["config"].update(**model_config)
config.update({"id": str(uuid4())})

# %%
with open("/home/kevin/workspace/Kaggle/Iceberg-Classifier-Challenge/study_configs/densenet.json", "w") as fp:
    json.dump(config, fp, indent=2)

# %%
config
# Out:
# {'data_source_delegate': {'name': 'DenseNet',
#   'parameters': {'batch_size': 32,
#    'testing_data_path': '/home/kevin/workspace/Kaggle/Iceberg-Classifier-Challenge/src/data/test.json',
#    'training_data_path': '/home/kevin/workspace/Kaggle/Iceberg-Classifier-Challenge/src/data/train.json'}},
#  'id': 'b3ab8115-6fc1-47b9-ae3e-b2caf85500c6',
#  'loss_function': {'name': 'BCELoss'},
#  'model': {'config': {'block_config': [6, 16, 24, 16],
#    'bottleneck_size': 4,
#    'denseblock_0.layer_0.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 32}},
#    'denseblock_0.layer_0.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_0.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 32,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_0.layer_0.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_0.layer_0.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_0.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_0.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_0.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_1.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 48}},
#    'denseblock_0.layer_1.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_1.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 48,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_0.layer_1.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_0.layer_1.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_1.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_1.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_1.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_2.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_2.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_2.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_0.layer_2.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_0.layer_2.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_2.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_2.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_2.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_3.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 80}},
#    'denseblock_0.layer_3.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_3.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 80,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_0.layer_3.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_0.layer_3.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_3.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_3.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_3.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_4.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 96}},
#    'denseblock_0.layer_4.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_4.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 96,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_0.layer_4.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_0.layer_4.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_4.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_4.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_4.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_0.layer_5.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 112}},
#    'denseblock_0.layer_5.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_0.layer_5.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 112,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_0.layer_5.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_0.layer_5.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_5.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_0.layer_5.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock
dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_15.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_15.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_2.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 304}},
#    'denseblock_3.layer_2.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_2.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 304,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_2.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_2.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_2.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_2.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_2.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_3.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 320}},
#    'denseblock_3.layer_3.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_3.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 320,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_3.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_3.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_3.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_3.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_3.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_4.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 336}},
#    'denseblock_3.layer_4.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_4.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 336,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_4.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_4.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_4.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_4.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_4.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_5.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 352}},
#    'denseblock_3.layer_5.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_5.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 352,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_5.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_5.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_5.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_5.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_5.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_6.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 368}},
#    'denseblock_3.layer_6.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_6.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 368,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_6.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_6.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_6.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_6.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_6.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_7.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 384}},
#    'denseblock_3.layer_7.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_7.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 384,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_7.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_7.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_7.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_7.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_7.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_8.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 400}},
#    'denseblock_3.layer_8.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_8.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 400,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_8.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_8.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_8.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_8.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_8.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_9.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 416}},
#    'denseblock_3.layer_9.batch_norm_1': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 64}},
#    'denseblock_3.layer_9.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 416,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'stride': 1}},
#    'denseblock_3.layer_9.conv_1': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 64,
#      'kernel_size': 3,
#      'out_channels': 16,
#      'padding': 1,
#      'stride': 1}},
#    'denseblock_3.layer_9.dropout_0': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_9.dropout_1': {'name': 'Dropout',
#     'parameters': {'p': 0.0}},
#    'denseblock_3.layer_9.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'denseblock_3.layer_9.non_linearity_1': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'growth_rate': 16,
#    'initial_block.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 32}},
#    'initial_block.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 3,
#      'kernel_size': 5,
#      'out_channels': 32,
#      'stride': 1}},
#    'initial_block.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'n_initial_features': 32,
#    'transition_0.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 128}},
#    'transition_0.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 128,
#      'kernel_size': 1,
#      'out_channels': 64,
#      'padding': 1,
#      'stride': 1}},
#    'transition_0.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'transition_0.pooling_0': {'name': 'AvgPool2d',
#     'parameters': {'kernel_size': 2, 'stride': 2}},
#    'transition_1.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 320}},
#    'transition_1.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 320,
#      'kernel_size': 1,
#      'out_channels': 160,
#      'padding': 1,
#      'stride': 1}},
#    'transition_1.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'transition_1.pooling_0': {'name': 'AvgPool2d',
#     'parameters': {'kernel_size': 2, 'stride': 2}},
#    'transition_2.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 544}},
#    'transition_2.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 544,
#      'kernel_size': 1,
#      'out_channels': 272,
#      'padding': 1,
#      'stride': 1}},
#    'transition_2.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'transition_2.pooling_0': {'name': 'AvgPool2d',
#     'parameters': {'kernel_size': 2, 'stride': 2}},
#    'transition_3.batch_norm_0': {'name': 'BatchNorm2d',
#     'parameters': {'num_features': 528}},
#    'transition_3.conv_0': {'name': 'Conv2d',
#     'parameters': {'bias': False,
#      'in_channels': 528,
#      'kernel_size': 1,
#      'out_channels': 264,
#      'padding': 1,
#      'stride': 1}},
#    'transition_3.non_linearity_0': {'name': 'LeakyReLU',
#     'parameters': {'inplace': True}},
#    'transition_3.pooling_0': {'name': 'AvgPool2d',
#     'parameters': {'kernel_size': 2, 'stride': 2}}},
#   'name': 'DenseNet'},
#  'n_epochs': 35,
#  'optimizer': {'name': 'ADAM',
#   'parameters': {'lr': 5e-05, 'weight_decay': 0.0001}},
#  'output_transformation': {'name': 'sigmoid'},
#  'saver_delegate': {'name': 'DenseNet'},
#  'trainer_delegate': {'name': 'DenseNet'}}
